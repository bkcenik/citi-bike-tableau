# %%
import pandas as pd
import glob

# %%
merged = pd.concat([pd.read_csv(f) for f in glob.glob('csv_files/*.csv')], ignore_index = True)

# %%
merged.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0          1635  2018-09-01 00:00:05.2690  2018-09-01 00:27:20.6340
# 1           132  2018-09-01 00:00:11.2810  2018-09-01 00:02:23.4810
# 2          3337  2018-09-01 00:00:20.6490  2018-09-01 00:55:58.5470
# 3           436  2018-09-01 00:00:21.7460  2018-09-01 00:07:38.5830
# 4          8457  2018-09-01 00:00:27.3150  2018-09-01 02:21:25.3080
#
#    start station id               start station name  start station latitude  \
# 0             252.0     MacDougal St & Washington Sq               40.732264
# 1             314.0  Cadman Plaza West & Montague St               40.693830
# 2            3142.0                  1 Ave & E 62 St               40.761227
# 3             308.0          St James Pl & Oliver St               40.713079
# 4             345.0                  W 13 St & 6 Ave               40.736494
#
#    start station longitude  end station id            end station name  \
# ...

# %%
merged["gender"].unique()
# Out:
# array([1, 0, 2])

# %%
merged["gender"]=merged["gender"].replace(1,"male")
merged["gender"]=merged["gender"].replace(2,"female")
merged["gender"]=merged["gender"].replace(0,"NA")
merged["gender"].unique()
merged["gender"].count
# Out:
# <bound method Series.count of 0             male
# 1               NA
# 2             male
# 3           female
# 4             male
# 5           female
# 6             male
# 7             male
# 8             male
# 9           female
# 10            male
# 11            male
# 12            male
# 13            male
# 14            male
# 15            male
# 16            male
# 17            male
# 18            male
# 19            male
# 20          female
# 21            male
# 22            male
# 23            male
# 24            male
# 25            male
# 26            male
# 27          female
# 28              NA
# 29            male
#              ...
# 18806924        NA
# 18806925      male
# 18806926      male
# 18806927      male
# 18806928      male
# 18806929      male
# 18806930    female
# 18806931      male
# 18806932      male
# 18806933      male
# 18806934    female
# 18806935      male
# 18806936      male
# 18806937      male
# 18806938      male
# ...

# %%
merged["Age"] = 2019 - merged["birth year"]
merged['trip duration min']=merged["tripduration"]/60
merged.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0          1635  2018-09-01 00:00:05.2690  2018-09-01 00:27:20.6340
# 1           132  2018-09-01 00:00:11.2810  2018-09-01 00:02:23.4810
# 2          3337  2018-09-01 00:00:20.6490  2018-09-01 00:55:58.5470
# 3           436  2018-09-01 00:00:21.7460  2018-09-01 00:07:38.5830
# 4          8457  2018-09-01 00:00:27.3150  2018-09-01 02:21:25.3080
#
#    start station id               start station name  start station latitude  \
# 0             252.0     MacDougal St & Washington Sq               40.732264
# 1             314.0  Cadman Plaza West & Montague St               40.693830
# 2            3142.0                  1 Ave & E 62 St               40.761227
# 3             308.0          St James Pl & Oliver St               40.713079
# 4             345.0                  W 13 St & 6 Ave               40.736494
#
#    start station longitude  end station id            end station name  \
# ...

# %%
merged.to_csv("merged.csv")

# %%
merged["start station name"].unique()
# Out:
# array(['MacDougal St & Washington Sq', 'Cadman Plaza West & Montague St',
#        '1 Ave & E 62 St', 'St James Pl & Oliver St', 'W 13 St & 6 Ave',
#        '31 St & 23 Ave', 'Christopher St & Greenwich St',
#        'Broadway & E 14 St', 'Fulton St & Broadway',
#        'Lenox Ave & W 115 St', 'Stagg St & Union Ave',
#        'Broadway & W 51 St', '3 Ave & E 62 St', '9 Ave & W 45 St',
#        'Bergen St & Vanderbilt Ave', 'Bedford Ave & Nassau Ave',
#        'Clinton St & Grand St', 'Smith St & 3 St', 'Avenue D & E 3 St',
#        'St Marks Pl & 2 Ave', 'W 31 St & 7 Ave', 'St Marks Pl & 1 Ave',
#        '37 Ave & 35 St', 'Johnson St & Gold St',
#        'South End Ave & Liberty St', 'W 22 St & 8 Ave',
#        'Pier 40 - Hudson River Park', '44 Dr & Jackson Ave',
#        'S 5 Pl & S 5 St', 'N 8 St & Driggs Ave', 'Forsyth St & Canal St',
#        'E 6 St & Avenue B', 'Lafayette St & E 8 St', '24 St & 41 Ave',
#        '1 Ave & E 16 St', 'Carroll St & 5 Ave',
# ...
